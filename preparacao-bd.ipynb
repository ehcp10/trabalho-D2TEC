# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
platform = pd.DataFrame(data['Platform'].unique())

# %%
genre = pd.DataFrame(data['Genre'].unique())
genre.fillna('N/D', inplace=True)
genre
# Out:
#                0
# 0         Sports
# 1       Platform
# 2         Racing
# 3   Role-Playing
# 4         Puzzle
# 5           Misc
# 6        Shooter
# 7     Simulation
# 8         Action
# 9       Fighting
# 10     Adventure
# 11      Strategy
# 12           N/D

# %%
publisher = pd.DataFrame(data['Publisher'].unique())
publisher.fillna('N/D', inplace=True)
publisher_dict = publisher.to_dict()
publisher_dict = publisher_dict[0]
publisher_dict
new_dict = dict(zip(publisher_dict.values(), publisher_dict.keys()))
new_dict
# Out:
# {'Nintendo': 0,
#  'Microsoft Game Studios': 1,
#  'Take-Two Interactive': 2,
#  'Sony Computer Entertainment': 3,
#  'Activision': 4,
#  'Ubisoft': 5,
#  'Bethesda Softworks': 6,
#  'Electronic Arts': 7,
#  'Sega': 8,
#  'SquareSoft': 9,
#  'Atari': 10,
#  '505 Games': 11,
#  'Capcom': 12,
#  'GT Interactive': 13,
#  'Konami Digital Entertainment': 14,
#  'Square Enix': 15,
#  'Sony Computer Entertainment Europe': 16,
#  'Virgin Interactive': 17,
#  'LucasArts': 18,
#  'Warner Bros. Interactive Entertainment': 19,
#  'Universal Interactive': 20,
#  'Eidos Interactive': 21,
#  'RedOctane': 22,
#  'Vivendi Games': 23,
#  'Enix Corporation': 24,
#  'Namco Bandai Games': 25,
#  'Palcom': 26,
#  'Hasbro Interactive': 27,
#  'THQ': 28,
#  'Fox Interactive': 29,
#  'Acclaim Entertainment': 30,
#  'MTV Games': 31,
#  'Disney Interactive Studios': 32,
#  'N/D': 33,
#  'Codemasters': 34,
#  'Majesco Entertainment': 35,
#  'Red Orb': 36,
#  'Level 5': 37,
#  'Arena Entertainment': 38,
#  'Midway Games': 39,
#  'JVC': 40,
#  'Deep Silver': 41,
#  'NCSoft': 42,
#  '989 Studios': 43,
#  'UEP Systems': 44,
#  'Parker Bros.': 45,
#  'Maxis': 46,
#  'Imagic': 47,
#  'Tecmo Koei': 48,
#  'ASCII Entertainment': 49,
#  'Valve Software': 50,
#  'Mindscape': 51,
#  'Infogrames': 52,
#  'Unknown': 53,
#  'Square': 54,
#  'Valve': 55,
#  'Banpresto': 56,
#  'Hello Games': 57,
#  'D3Publisher': 58,
#  'Activision Value': 59,
#  'Oxygen Interactive': 60,
#  'Red Storm Entertainment': 61,
#  'Video System': 62,
#  'Global Star': 63,
#  'Gotham Games': 64,
#  'Westwood Studios': 65,
#  'GungHo': 66,
#  'Crave Entertainment': 67,
#  'Hudson Soft': 68,
#  'Coleco': 69,
#  'Rising Star Games': 70,
#  'TDK Mediactive': 71,
#  'ASC Games': 72,
#  'Accolade': 73,
#  'Zoo Games': 74,
#  'Sony Online Entertainment': 75,
#  '3DO': 76,
#  'Natsume': 77,
#  'RTL': 78,
#  'Alchemist': 79,
#  'Black Label Games': 80,
#  'SouthPeak Games': 81,
#  'Focus Home Interactive': 82,
#  'Ocean': 83,
#  'Zoo Digital Publishing': 84,
#  'Psygnosis': 85,
#  'City Interactive': 86,
#  'Empire Interactive': 87,
#  'Success': 88,
#  'Compile': 89,
#  'Russel': 90,
#  'Atlus': 91,
#  'Mastertronic': 92,
#  'Slightly Mad Studios': 93,
#  'Taito': 94,
#  'Agetec': 95,
#  'Microprose': 96,
#  'Play It': 97,
#  'GSP': 98,
#  'Tomy Corporation': 99,
#  'Sammy Corporation': 100,
#  'Koch Media': 101,
#  'Game Factory': 102,
#  'Titus': 103,
#  'Marvelous Entertainment': 104,
#  'Genki': 105,
#  'Mojang': 106,
#  'CTO SpA': 107,
#  'TalonSoft': 108,
#  'Crystal Dynamics': 109,
#  'Square Enix ': 110,
#  'mixi, Inc': 111,
#  'Pinnacle': 112,
#  'SCi': 113,
#  'Quelle': 114,
#  'Rage Software': 115,
#  'Ubisoft Annecy': 116,
#  'Interplay': 117,
#  'Scholastic Inc.': 118,
#  'Mystique': 119,
#  'ChunSoft': 120,
#  'Square EA': 121,
#  '20th Century Fox Video Games': 122,
#  'Hudson Entertainment': 123,
#  'Men-A-Vision': 124,
#  'Nobilis': 125,
#  'Avanquest Software': 126,
#  'Big Ben Interactive': 127,
#  'Nordic Games': 128,
#  'Touchstone': 129,
#  'Spike': 130,
#  'Nippon Ichi Software': 131,
#  'Sony Computer Entertainment America': 132,
#  'Jester Interactive': 133,
#  'LEGO Media': 134,
#  'Quest': 135,
#  'Illusion Softworks': 136,
#  'Tigervision': 137,
#  'Rocket Company': 138,
#  'Metro 3D': 139,
#  'Mattel Interactive': 140,
#  'IE Institute': 141,
#  'Funbox Media': 142,
#  'Rondomedia': 143,
#  'Universal Gamex': 144,
#  'Ghostlight': 145,
#  'Wizard Video Games': 146,
#  'BMG Interactive Entertainment': 147,
#  'PQube': 148,
#  'Trion Worlds': 149,
#  'Xseed Games': 150,
#  'Laguna': 151,
#  'Takara': 152,
#  'Ignition Entertainment': 153,
#  'Kadokawa Shoten': 154,
#  'Enterbrain': 155,
#  'Imagineer': 156,
#  'CPG Products': 157,
#  'System 3 Arcade Software': 158,
#  'Aruze Corp': 159,
#  'Destineer': 160,
#  'Gamebridge': 161,
#  'Midas Interactive Entertainment': 162,
#  'Jaleco': 163,
#  'Answer Software': 164,
#  'Pack In Soft': 165,
#  'XS Games': 166,
#  'Rebellion': 167,
#  'Ultravision': 168,
#  'Harmonix Music Systems': 169,
#  'Activision Blizzard': 170,
#  'Xplosiv': 171,
#  'Wanadoo': 172,
#  'Telltale Games': 173,
#  'NovaLogic': 174,
#  'Epoch': 175,
#  'BAM! Entertainment': 176,
#  'GameMill Entertainment': 177,
#  'Knowledge Adventure': 178,
#  'Tetris Online': 179,
#  'Mastiff': 180,
#  'ESP': 181,
#  'TYO': 182,
#  'Telegames': 183,
#  'Mud Duck Productions': 184,
#  'Screenlife': 185,
#  'Pioneer LDC': 186,
#  'Magical Company': 187,
#  'Kemco': 188,
#  'Mentor Interactive': 189,
#  'Human Entertainment': 190,
#  'Data Age': 191,
#  'Electronic Arts Victor': 192,
#  'Jack of All Games': 193,
#  'Avanquest': 194,
#  'Black Bean Games': 195,
#  '989 Sports': 196,
#  'Takara Tomy': 197,
#  'Media Rings': 198,
#  'Elf': 199,
#  'Starfish': 200,
#  'Zushi Games': 201,
#  'Jorudan': 202,
#  'Destination Software, Inc': 203,
#  'New': 204,
#  'Brash Entertainment': 205,
#  'Kalypso Media': 206,
#  'ITT Family Games': 207,
#  'Ackkstudios': 208,
#  'PopCap Games': 209,
#  'Starpath Corp.': 210,
#  'BPS': 211,
#  'Gathering of Developers': 212,
#  'NewKidCo': 213,
#  'Marvelous Interactive': 214,
#  'Storm City Games': 215,
#  'CokeM Interactive': 216,
#  'P2 Games': 217,
#  'CBS Electronics': 218,
#  'Home Entertainment Suppliers': 219,
#  'Magix': 220,
#  'Arc System Works': 221,
#  'Angel Studios': 222,
#  'Wargaming.net': 223,
#  'Playmates': 224,
#  'SNK Playmore': 225,
#  'Hamster Corporation': 226,
#  'From Software': 227,
#  'Nippon Columbia': 228,
#  'Nichibutsu': 229,
#  'Conspiracy Entertainment': 230,
#  'Hect': 231,
#  'Mumbo Jumbo': 232,
#  'DTP Entertainment': 233,
#  'Pacific Century Cyber Works': 234,
#  'Indie Games': 235,
#  'Liquid Games': 236,
#  'NEC': 237,
#  'Axela': 238,
#  'ArtDink': 239,
#  'Sunsoft': 240,
#  'Little Orbit': 241,
#  'FuRyu': 242,
#  'Gust': 243,
#  'SNK': 244,
#  'NEC Interchannel': 245,
#  'Nihon Falcom Corporation': 246,
#  'Xing Entertainment': 247,
#  'ValuSoft': 248,
#  'Victor Interactive': 249,
#  'American Softworks': 250,
#  'Falcom Corporation': 251,
#  'Detn8 Games': 252,
#  'Bomb': 253,
#  'Nordcurrent': 254,
#  'Milestone S.r.l.': 255,
#  'AQ Interactive': 256,
#  'Sears': 257,
#  'Seta Corporation': 258,
#  'On Demand': 259,
#  'CCP': 260,
#  'NCS': 261,
#  'Rebellion Developments': 262,
#  'Agatsuma Entertainment': 263,
#  'Gremlin Interactive Ltd': 264,
#  'Aspyr': 265,
#  'Compile Heart': 266,
#  'Culture Brain': 267,
#  'Mad Catz': 268,
#  'Shogakukan': 269,
#  'Merscom LLC': 270,
#  'JoWood Productions': 271,
#  'Nippon Telenet': 272,
#  'TDK Core': 273,
#  'Kadokawa Games': 274,
#  'SSI': 275,
#  'Foreign Media Games': 276,
#  'Core Design Ltd.': 277,
#  'bitComposer Games': 278,
#  'Astragon': 279,
#  'Asylum Entertainment': 280,
#  'Performance Designed Products': 281,
#  'UFO Interactive': 282,
#  'Essential Games': 283,
#  'Adeline Software': 284,
#  'Funcom': 285,
#  'PlayV': 286,
#  'Panther Software': 287,
#  'Blast! Entertainment Ltd': 288,
#  'Playlogic Game Factory': 289,
#  'DSI Games': 290,
#  'Avalon Interactive': 291,
#  'Game Life': 292,
#  'Popcorn Arcade': 293,
#  'Aques': 294,
#  'System 3': 295,
#  'Syscom': 296,
#  'Vir2L Studios': 297,
#  'Vatical Entertainment': 298,
#  'Neko Entertainment': 299,
#  'White Park Bay Software': 300,
#  'Vic Tokai': 301,
#  'Media Factory': 302,
#  'Daedalic': 303,
#  'Game Arts': 304,
#  'The Adventure Company': 305,
#  'EA Games': 306,
#  'Acquire': 307,
#  'Broccoli': 308,
#  'General Entertainment': 309,
#  'Paradox Interactive': 310,
#  'Yacht Club Games': 311,
#  'Imadio': 312,
#  'Swing! Entertainment': 313,
#  'Sony Music Entertainment': 314,
#  'Aqua Plus': 315,
#  'Excalibur Publishing': 316,
#  'Hip Interactive': 317,
#  'Tripwire Interactive': 318,
#  'DreamCatcher Interactive': 319,
#  'SCS Software': 320,
#  'Havas Interactive': 321,
#  'Sting': 322,
#  'Idea Factory': 323,
#  'Telstar': 324,
#  'U.S. Gold': 325,
#  'Funsta': 326,
#  'DreamWorks Interactive': 327,
#  'Slitherine Software': 328,
#  'MTO': 329,
#  'Graffiti': 330,
#  'Tru Blu Entertainment': 331,
#  'DHM Interactive': 332,
#  'Crytek': 333,
#  'FunSoft': 334,
#  'Data Design Interactive': 335,
#  'SPS': 336,
#  'Moss': 337,
#  'T&E Soft': 338,
#  'NDA Productions': 339,
#  'Bigben Interactive': 340,
#  'Data East': 341,
#  'Idea Factory International': 342,
#  'Time Warner Interactive': 343,
#  'Gainax Network Systems': 344,
#  'Daito': 345,
#  'O3 Entertainment': 346,
#  'O-Games': 347,
#  'Gameloft': 348,
#  'Xicat Interactive': 349,
#  'Simon & Schuster Interactive': 350,
#  'Valcon Games': 351,
#  'PopTop Software': 352,
#  'TOHO': 353,
#  'PM Studios': 354,
#  'Bohemia Interactive': 355,
#  'Reef Entertainment': 356,
#  '5pb': 357,
#  'HMH Interactive': 358,
#  'inXile Entertainment': 359,
#  'Cave': 360,
#  'Microids': 361,
#  'Paon': 362,
#  'CDV Software Entertainment': 363,
#  'Micro Cabin': 364,
#  'GameTek': 365,
#  'Benesse': 366,
#  'Type-Moon': 367,
#  'Enjoy Gaming ltd.': 368,
#  'Asmik Corp': 369,
#  'Interplay Productions': 370,
#  'Asmik Ace Entertainment': 371,
#  'Image Epoch': 372,
#  'Phantom EFX': 373,
#  'Evolved Games': 374,
#  'responDESIGN': 375,
#  'Griffin International': 376,
#  'Culture Publishers': 377,
#  'Hackberry': 378,
#  'Hearty Robin': 379,
#  'Nippon Amuse': 380,
#  'Origin Systems': 381,
#  'Seventh Chord': 382,
#  'Abylight': 383,
#  'Mitsui': 384,
#  'Insomniac Games': 385,
#  'Flight-Plan': 386,
#  'Milestone': 387,
#  'Glams': 388,
#  'Aksys Games': 389,
#  'Locus': 390,
#  'Warp': 391,
#  'Irem Software Engineering': 392,
#  'Myelin Media': 393,
#  'Global A Entertainment': 394,
#  'Alternative Software': 395,
#  'Mercury Games': 396,
#  'Sunrise Interactive': 397,
#  'Elite': 398,
#  'Evolution Games': 399,
#  'Daedalic Entertainment': 400,
#  'Edia': 401,
#  'Athena': 402,
#  'Aria': 403,
#  'Tivola': 404,
#  'Happinet': 405,
#  'Tommo': 406,
#  'Altron': 407,
#  'Revolution Software': 408,
#  'Media Works': 409,
#  'Fortyfive': 410,
#  'Gamecock': 411,
#  'Imax': 412,
#  '10TACLE Studios': 413,
#  'Groove Games': 414,
#  'Pack-In-Video': 415,
#  'Crimson Cow': 416,
#  'iWin': 417,
#  'Asgard': 418,
#  'Ecole': 419,
#  'Yumedia': 420,
#  'Ascaron Entertainment GmbH': 421,
#  'HAL Laboratory': 422,
#  'Phenomedia': 423,
#  'Grand Prix Games': 424,
#  'DigiCube': 425,
#  'Creative Core': 426,
#  'Kaga Create': 427,
#  'WayForward Technologies': 428,
#  'LSP Games': 429,
#  'ASCII Media Works': 430,
#  '1C Company': 431,
#  'Coconuts Japan': 432,
#  'Arika': 433,
#  'Marvel Entertainment': 434,
#  'Ertain': 435,
#  'Prototype': 436,
#  'Phantagram': 437,
#  'The Learning Company': 438,
#  'TechnoSoft': 439,
#  'MLB.com': 440,
#  'Vap': 441,
#  'Misawa': 442,
#  'Yeti': 443,
#  'Dusenberry Martin Racing': 444,
#  'Navarre Corp': 445,
#  'Pow': 446,
#  'MediaQuest': 447,
#  'Team17 Software': 448,
#  'Max Five': 449,
#  'Tradewest': 450,
#  'Comfort': 451,
#  'Milestone S.r.l': 452,
#  'Pony Canyon': 453,
#  'Riverhillsoft': 454,
#  'Summitsoft': 455,
#  'Playmore': 456,
#  'Kool Kizz': 457,
#  'Monte Christo Multimedia': 458,
#  'TopWare Interactive': 459,
#  'Legacy Interactive': 460,
#  'Cloud Imperium Games Corporation': 461,
#  'Flashpoint Games': 462,
#  'CyberFront': 463,
#  'Alawar Entertainment': 464,
#  'Societa': 465,
#  'Interchannel': 466,
#  'Experience Inc.': 467,
#  'Sonnet': 468,
#  'Virtual Play Games': 469,
#  'Zenrin': 470,
#  'Iceberg Interactive': 471,
#  'Ivolgamus': 472,
#  'MC2 Entertainment': 473,
#  '2D Boy': 474,
#  'Games Workshop': 475,
#  'Kando Games': 476,
#  'Office Create': 477,
#  'Maximum Family Games': 478,
#  'Fields': 479,
#  'Gearbox Software': 480,
#  'Princess Soft': 481,
#  'Extreme Entertainment Group': 482,
#  'Big Fish Games': 483,
#  'Berkeley': 484,
#  'Mamba Games': 485,
#  'Fuji': 486,
#  'FuRyu Corporation': 487,
#  'Her Interactive': 488,
#  'imageepoch Inc.': 489,
#  'Just Flight': 490,
#  'Kamui': 491,
#  'ASK': 492,
#  'Cygames': 493,
#  'Introversion Software': 494,
#  '49Games': 495,
#  'KSS': 496,
#  'dramatic create': 497,
#  'TGL': 498,
#  'KID': 499,
#  'Quinrose': 500,
#  'Sold Out': 501,
#  'Encore': 502,
#  'G.Rev': 503,
#  'Sunflowers': 504,
#  'Headup Games': 505,
#  'Sweets': 506,
#  'Kokopeli Digital Studios': 507,
#  'id Software': 508,
#  'Nexon': 509,
#  'BushiRoad': 510,
#  'Devolver Digital': 511,
#  'Number None': 512,
#  'Tryfirst': 513,
#  'GN Software': 514,
#  "Yuke's": 515,
#  'Strategy First': 516,
#  'Lexicon Entertainment': 517,
#  'Paon Corporation': 518,
#  'Kids Station': 519,
#  'Licensed 4U': 520,
#  'GOA': 521,
#  '7G//AMES': 522,
#  'King Records': 523,
#  'Minato Station': 524,
#  'Graphsim Entertainment': 525,
#  'Easy Interactive': 526,
#  'Gaga': 527,
#  'Yamasa Entertainment': 528,
#  'Plenty': 529,
#  'Views': 530,
#  'Blue Byte': 531,
#  'fonfun': 532,
#  'NetRevo': 533,
#  'Epic Games': 534,
#  'Quintet': 535,
#  'Focus Multimedia': 536,
#  'Phoenix Games': 537,
#  'Marvelous Games': 538,
#  'Dorart': 539,
#  'Codemasters Online': 540,
#  'Stainless Games': 541,
#  'Aerosoft': 542,
#  'Imageworks': 543,
#  'Karin Entertainment': 544,
#  'Technos Japan Corporation': 545,
#  'Masque Publishing': 546,
#  'Gakken': 547,
#  'New World Computing': 548,
#  'Mirai Shounen': 549,
#  'Datam Polystar': 550,
#  'HuneX': 551,
#  'Visco': 552,
#  'Saurus': 553,
#  'Revolution (Japan)': 554,
#  'Giza10': 555,
#  'Alvion': 556,
#  'Giga': 557,
#  'Mycom': 558,
#  'Warashi': 559,
#  'System Soft': 560,
#  'RED Entertainment': 561,
#  'Lighthouse Interactive': 562,
#  'Michaelsoft': 563,
#  'Media Entertainment': 564,
#  'Genterprise': 565,
#  'Interworks Unlimited, Inc.': 566,
#  'Inti Creates': 567,
#  'Boost On': 568,
#  'EON Digital Entertainment': 569,
#  'Nitroplus': 570,
#  'Naxat Soft': 571,
#  'Piacci': 572,
#  'Paradox Development': 573,
#  'Otomate': 574,
#  'Ascaron Entertainment': 575,
#  'Ongakukan': 576,
#  'Commseed': 577,
#  'UIG Entertainment': 578,
#  'Takuyo': 579,
#  'Interchannel-Holon': 580,
#  'Red Flagship': 581}

# %%
na_sales = pd.DataFrame(data['NA_Sales'].unique())
eu_sales = pd.DataFrame(data['EU_Sales'].unique())
jp_sales = pd.DataFrame(data['JP_Sales'].unique())
ot_sales = pd.DataFrame(data['Other_Sales'].unique())
global_sales = pd.DataFrame(data['Global_Sales'].unique())

# %%
critic_score = pd.DataFrame(data['Critic_Score'].unique())
user_score = pd.DataFrame(data['User_Score'].unique())

# %%
# pa = pd.DataFrame(data['Platform'].unique())
# publisher.fillna('N/D', inplace=True)
platform_dict = platform.to_dict()
platform_dict = platform_dict[0]
platform_dict
new_plat_dict = dict(zip(platform_dict.values(), platform_dict.keys()))
new_plat_dict
# Out:
# {'Wii': 0,
#  'NES': 1,
#  'GB': 2,
#  'DS': 3,
#  'X360': 4,
#  'PS3': 5,
#  'PS2': 6,
#  'SNES': 7,
#  'GBA': 8,
#  'PS4': 9,
#  '3DS': 10,
#  'N64': 11,
#  'PS': 12,
#  'XB': 13,
#  'PC': 14,
#  '2600': 15,
#  'PSP': 16,
#  'XOne': 17,
#  'WiiU': 18,
#  'GC': 19,
#  'GEN': 20,
#  'DC': 21,
#  'PSV': 22,
#  'SAT': 23,
#  'SCD': 24,
#  'WS': 25,
#  'NG': 26,
#  'TG16': 27,
#  '3DO': 28,
#  'GG': 29,
#  'PCFX': 30}

# %%
# %pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /home/evandrocouto/pos/D2APR/d2apr/lib/python3.9/site-packages (8.0.26)
# Requirement already satisfied: protobuf>=3.0.0 in /home/evandrocouto/pos/D2APR/d2apr/lib/python3.9/site-packages (from mysql-connector-python) (3.18.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as sql

# %%
db_connection = sql.connect(host='localhost', database='games', user='root', password='123456', port=3303)
db_cursor = db_connection.cursor()

# %%
for index, row in platform.iterrows():
    query = "INSERT INTO plataforma(nome) VALUES (%s)"
    db_cursor.execute(query, (row[0],))
    db_connection.commit()
#     print("Inserted",db_cursor.rowcount,"row(s) of data.")

# %%
for index, row in genre.iterrows():
    query = "INSERT INTO genero(nome) VALUES(%s)"
    db_cursor.execute(query, (row[0],))
    db_connection.commit()
#     print("Inserted",db_cursor.rowcount,"row(s) of data.")

# %%
for index, row in publisher.iterrows():
    query = "INSERT INTO publisher(nome) VALUES(%s)"
    db_cursor.execute(query, (row[0],))
#     print("Inserted",db_cursor.rowcount,"row(s) of data.")

# %%
cp_data = data[['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher']]
cp_data.fillna('N/D', inplace=True)

# %%
cp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16719 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16719 non-null  object
#  3   Genre            16719 non-null  object
#  4   Publisher        16719 non-null  object
# dtypes: object(5)
# memory usage: 653.2+ KB

# %%
# cp_games_data = cp_data.replace({'Platform', new_dict })

cp_games_data = cp_data['Publisher'].map(new_dict)
cp_games_plat_data = cp_data['Platform'].map(new_plat_dict)
cp_games_data
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 16714     48
# 16715     34
# 16716    323
# 16717    172
# 16718     48
# Name: Publisher, Length: 16719, dtype: int64
